# %%
import os
import cv2

# %%
def extract_frames(folder_name, video_name, output_folder, image_format, frame_rate):
    """
    Функция разбивает видео на фреймы и сохраняет их.

    :param folder_name: Название папки с видеофайлами.
    :param video_name: Название видео.
    :param output_folder: Папка для сохранения фреймов.
    :param image_format: Формат сохранения изображений фреймов.
    :param frame_rate: Частота выборки фреймов (каждый N-й фрейм).
    """
    video_name_without_ext = ''.join(video_name.split('.')[:-1])
    video_full_path = os.path.join(output_folder, video_name_without_ext)
    video_full_path_frame_rate = os.path.join(video_full_path, f'frame_rate_{frame_rate}')
                                                
    # Создание папки для сохранения фреймов
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Создание папки для сохранения фреймов видео video_name
    if not os.path.exists(video_full_path):
        os.makedirs(video_full_path)
    
    # Создание папки для сохранения фреймов видео video_name с частотой frame_rate
    if not os.path.exists(video_full_path_frame_rate):
        os.makedirs(video_full_path_frame_rate)
    # Иначе чистим папку и по новой записываем
    else:
        frame_files = os.listdir(video_full_path_frame_rate)
        for frame_path in map(lambda x: os.path.join(video_full_path_frame_rate, x), frame_files):
            os.remove(frame_path)
    
    # Открытие видеофайла
    path_to_video = os.path.join(folder_name, video_name)
    
    cap = cv2.VideoCapture(path_to_video)
    if not cap.isOpened():
        raise Exception(f"Не удалось открыть видео {path_to_video}")

    # Инициализация счётчика фреймов
    frame_count = 0
    saved_frame_count = 0

    while True:
        ret, frame = cap.read()
        
        if not ret:
            # Конец видео
            break  

        # Сохраняем только каждый frame_rate-й фрейм
        if frame_count % frame_rate == 0:
            frame_filename = os.path.join(video_full_path_frame_rate, f"frame_{saved_frame_count:04d}.{image_format}")
            
            frame = cv2.resize(frame, (512, 512))
            
            cv2.imwrite(frame_filename, frame)
            saved_frame_count += 1

        frame_count += 1

    # Освобождение ресурсов
    cap.release()
    print(f"Сохранено {saved_frame_count} фреймов в папку {video_full_path_frame_rate}")

# %%
folder_name = "videos"
video_names = os.listdir('videos')
output_folder = "videos_frames"
image_format = 'jpg'
frame_rate = 1

for video_name in video_names:
    if video_name[0] != '.':
        extract_frames(folder_name, video_name, output_folder, image_format, frame_rate)
# Out:
# Сохранено 177 фреймов в папку videos_frames/video — копия 39/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 11/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/8dd353f8-362e-427d-bead-c7499d084e56/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/097c0732-edb6-45ac-8fff-695e9e3e4a3a/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/c3868346-48d4-4607-8901-c5416fee9041/frame_rate_1
# Сохранено 120 фреймов в папку videos_frames/video — копия 3/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/2343f4fc-8ff5-4eb1-9a9b-9938d7056cf9/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/2025-04-30_22-10-33_KANDINSKY_VIDEO_320188213/frame_rate_1
# Сохранено 240 фреймов в папку videos_frames/a/frame_rate_1
# Сохранено 121 фреймов в папку videos_frames/Gen-4 Turbo a animated video of a knight pulling out his sword from his back 2592794189/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/a0a1d055-eb80-4d2c-9d50-15570d9fe3a4/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/69d76f0f-a186-4a9d-a244-f52960e0cf0c/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/man swimming in ocean waves/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/an ant and an elephant going on dating/frame_rate_1
# Сохранено 121 фреймов в папку videos_frames/Broadcast_footage_The_pet_is_a_news_anchor_sitting_behind_a_desk,_a_microphone_and_papers_in_front__seed2284197787_share/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/a labrador dog walking on the beach in the sunset/frame_rate_1
# Сохранено 121 фреймов в папку videos_frames/video — копия 2/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/b16fff45-fe06-40b2-bb35-8bec05eee04e/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/5fc60a54-81a7-4330-823c-e9f035493b57/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 10/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 38/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 12/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/290cb4fa-909c-46d1-94a5-460126d48ea9/frame_rate_1
# Сохранено 121 фреймов в папку videos_frames/Gen-4 Turb
KANDINSKY_VIDEO_320188213/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/ad8165bd-4ad8-42d6-bb38-dede9fddf4e4/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/b10c0487-d2a1-47b8-ae36-4bca9ec553f0/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/2025-04-30_16-24-39_KANDINSKY_VIDEO_320188213/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/group of people chatting with cell phone in the hand/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/7fd61d63-a54f-440c-be8c-63d275188568/frame_rate_1
# Сохранено 121 фреймов в папку videos_frames/video_share — копия 4/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 25/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 31/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 19/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 27/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 33/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/5e5b57bb-a1a6-4354-9184-948bfc5ce58f/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 9/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/e432086a-e8d7-407f-b90e-dd1dadb63a9e/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/41198948-142b-4b9d-98ee-494fa33def65/frame_rate_1
# Сохранено 121 фреймов в папку videos_frames/Gen-4 Turbo air balloons are flying in the sky 1719216739/frame_rate_1
# Сохранено 300 фреймов в папку videos_frames/023-20241207_0303_Innocent Wonder_storyboard_01jegck6zpeh9vysdh219g32j5mp4/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 8/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 32/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 26/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/e01f0e2b-969d-4eb0-939c-7c8c9df0c36b/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/895b4e52-84ef-4d36-8fab-3ee217297793/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 22/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 36/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/ancient gods have an epic fight on earth/frame_rate_1
# Сохранено 121 фреймов в папку videos_frames/video_share — копия 3/frame_rate_1
# Сохранено 121 фреймов в папку videos_frames/the cat flying in the air/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/f299c586-0582-4b0d-a669-6a1003437d04/frame_rate_1
# Сохранено 121 фреймов в папку videos_frames/video_share — копия 2/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/5284dac0-8ef5-4640-8a8e-50aebe50a747/frame_rate_1
# Сохранено 121 фреймов в папку videos_frames/Gen-4 Turbo a man is smoking a cigarette and looks away 937519435/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 37/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 23/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 35/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 21/frame_rate_1
# Сохранено 121 фреймов в папку videos_frames/Gen-4 Turbo a couple eating and laughing  2168079613/frame_rate_1
# Сохранено 121 фреймов в папку videos_frames/video_share/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/b4f8c311-b631-4cd3-ac63-d6ad725b5692/frame_rate_1
# Сохранено 300 фреймов в папку videos_frames/011-20241206_1608_Alien Ship Emergence_storyboard_01jef74b47ezrvx8wh7f4bgn1dmp4/frame_rate_1
# Сохранено 300 фреймов в папку videos_frames/021-20241207_0322_Bears_ Sushi Feast_storyboard_01jegdnrn2e5p8m4mew6q6215bmp4/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/a boy riding a dinosaur/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 20/frame_rate_1
# Сохранено 81 фреймов в папку videos_frames/0e0c97a1-978a-464e-af70-fbdbeb5de0b1/frame_rate_1
# Сохранено 177 фреймов в папку videos_frames/video — копия 34/frame_rate_1

# %%
len(os.listdir('videos_frames'))
# Out:
# 200

# %%
sorted(os.listdir('videos_frames'))
# Out:
# ['010-7_20241120_2300_Harmony with Nature_simple_compose_01jd6ras77f01s8we76f97xsvm (2)mp4',
#  '011-20241206_1608_Alien Ship Emergence_storyboard_01jef74b47ezrvx8wh7f4bgn1dmp4',
#  '013-20241205_1850_Loop Video_loop_01jecxzmtfesctgnq085gj8cabmp4',
#  '015ff8b9-f9ca-4147-8ef7-3bf29ebd9fcb',
#  '0160a813-f73a-432c-adf9-f2b94da67aa3',
#  '019-20241204_0022_Golden Festive Frolic_simple_compose_01je8c5v26fpj8jeydjp6gymy9mp4',
#  '021-20241207_0322_Bears_ Sushi Feast_storyboard_01jegdnrn2e5p8m4mew6q6215bmp4',
#  '023-20241207_0303_Innocent Wonder_storyboard_01jegck6zpeh9vysdh219g32j5mp4',
#  '024-20241207_0103_Bubble Dragon Delight_simple_compose_01jeg5pwjpf13vze4vpf1ybg3cmp4',
#  '03d66206-53f0-4738-82bd-2e8116fd374c',
#  '070474a4-494b-45a1-b471-97385045de57',
#  '08ba26a3-4496-481b-b799-541144db1318',
#  '097c0732-edb6-45ac-8fff-695e9e3e4a3a',
#  '0bf92fb5-1f34-4486-b28a-e3e6411e7158',
#  '0e0c97a1-978a-464e-af70-fbdbeb5de0b1',
#  '0ea15e40-e8bc-49ab-af31-5f6a8a8f6a7f',
#  '2025-04-29_19-14-03_KANDINSKY_VIDEO_320188213',
#  '2025-04-30
#  'Broadcast_footage_The_pet_is_a_news_anchor_sitting_behind_a_desk,_a_microphone_and_papers_in_front__seed2284197787_share',
#  'Gen-4 Turbo A group of young people racing motorcycles 2592794189',
#  'Gen-4 Turbo A man juggles 4 red balls 2409341675',
#  'Gen-4 Turbo A monkey takes a selfie in front of the Eiffel Tower and laughs 773685535',
#  'Gen-4 Turbo A pirate ship is sailing in the sea, zoom in 2168079613',
#  'Gen-4 Turbo Clouds and heavy rain are coming towards the new york city 773685535',
#  'Gen-4 Turbo Harry Potter and Voldemort are fighting Harry Potter wins 2168079613',
#  'Gen-4 Turbo The girl puts the pizza in the oven and closes it 2168079613',
#  'Gen-4 Turbo The helicopter takes off into the air, the weather is shiny, zoom out 2409341675',
#  'Gen-4 Turbo The wind bursts into the open window, lifting the curtains 2592794189',
#  'Gen-4 Turbo Young guys are sitting around a campfire and chatting 2168079613',
#  'Gen-4 Turbo a animated video of a knight pulling out his sword from his back 2592794189',
#  'Gen-4 Turbo a bear jumps from a wood pole and flies away from the camera, zoom out 773685535',
#  'Gen-4 Turbo a bear roars and then run towards camera 773685535',
#  'Gen-4 Turbo a boy makes a dinner in the kitchen 937519435',
#  'Gen-4 Turbo a couple drinking tea in front of mountains man makes a proposal and after a firework appears in the background 117935208',
#  'Gen-4 Turbo a couple eating and laughing  2168079613',
#  'Gen-4 Turbo a family have a bicycle ride in the forest 2409341675',
#  'Gen-4 Turbo a girl is opening the book and flipping through the pages 117935208',
#  'Gen-4 Turbo a hand in a glove takes a glass 1719216739',
#  'Gen-4 Turbo a man is smoking a cigarette and looks away 937519435',
#  'Gen-4 Turbo a person plays the piano masterfully 937519435',
#  'Gen-4 Turbo a world war 2 planes flying 2592794189',
#  'Gen-4 Turbo air balloons are flying in the sky 1719216739',
#  'Gen-4 Turbo an old man fishing in the boat 2592794189',
#  'Gen-4 Turbo astronauts wave to each other in the space 773685535',
#  'Gen-4 Turbo children enjoy spending time on the playground The boy slides down the slide 117935208',
#  'Gen-4 Turbo family spends their pastime in the park together 937519435',
#  'Gen-4 Turbo in the windows there is life happening in one window people are talking in another people are eating one window was opened and person looked around one window is being washed by housek',
#  'Gen-4 Turbo lion and tiger are fighting 2409341675',
#  'Gen-4 Turbo newly married couple take an oath to each other 1719216739',
#  'Gen-4 Turbo people enjoy the landscape of the mountains and sit near the river river flows zoom in 937519435',
#  'Gen-4 Turbo police is arresting a person 117935208',
#  'Gen-4 Turbo pupils listen to the teacher and write in the notebooks 2409341675',
#  'Gen-4 Turbo the plane takes off from the runway 1719216739',
#  'Gen-4 Turbo two friends are sitting on the balcony and smoking cigarettes 1719216739',
#  'a',
#  'a (1)',
#  'a boy riding a dinosaur',
#  'a labrador dog walking on the beach in the sunset',
#  'a lion running in jungle',
#  'a modern flying car above the city skycrapers',
#  'a tornado destroys a house',
#  'a0a1d055-eb80-4d2c-9d50-15570d9fe3a4',
#  'a54feb64-9b17-459c-a7f9-aa6718ab3563',
#  'abd71679-c8f8-4ae0-a467-92ee1edb0ddb',
#  'ad8165bd-4ad8-42d6-bb38-dede9fddf4e4',
#  'ae140222-149d-4042-95c9-124c88d495b1',
#  'af41f0c3-195a-458c-a891-0c55fcd14a82',
#  'afro american guy run through Saturn planet ring',
#  'an ant and an elephant going on dating',
#  'ancient gods have an epic fight on earth',
#  'a\xa0— копия',
#  'b',
#  'b0c602ee-54a8-490f-9e9b-2425235efb41',
#  'b10c0487-d2a1-47b8-ae36-4bca9ec553f0',
#  'b10f419c-5443-40c7-b888-49a2f73da422',
#  'b16fff45-fe06-40b2-bb35-8bec05eee04e',
#  'b4f8c311-b631-4cd3-ac63-d6ad725b5692',
#  'bedc5408-cd9f-4327-a8a1-2df10c6cf638',
#  'b\xa0— копия',
#  'c',
#  'c3868346-48d4-4607-8901-c5416fee9041',
#  'c9d660d4-009e-439a-bfe4-c4fcf1014ae4',
#  'd',
#  'd8441d32-62a0-4802-8cc9-c72000d20545',
#  'def6089c-4758-4071-8f5f-e145005cd547',
#  'd\xa0— копия',
#  'e01f0e2b-969d-4eb0-939c-7c8c9df0c36b',
#  'e06144c8-d8df-407b-bd07-ae0764b39814',
#  'e432086a-e8d7-407f-b90e-dd1dadb63a9e',
#  'e6ba946f-79be-4962-95a8-6a190a573247',
#  'e7e0f0f7-121c-441d-b645-e2040fcd71fe',
#  'ea8bac16-cfff-4a30-94ec-62c654293449',
#  'ecf6567f-39c1-4c83-b7e6-46c7ba591db9',
#  'f299c586-0582-4b0d-a669-6a1003437d04',
#  'group of people chatting with cell phone in the hand',
#  'man swimming in ocean waves',
#  'the cat flying in the air',
#  'twin brothers fighting over a truck',
#  'video',
#  'video_share',
#  'video_share\xa0— копия',
#  'video_share\xa0— копия 2',
#  'video_share\xa0— копия 3',
#  'video_share\xa0— копия 4',
#  'video_share\xa0— копия 5',
#  'video\xa0— копия',
#  'video\xa0— копия 10',
#  'video\xa0— копия 11',
#  'video\xa0— копия 12',
#  'video\xa0— копия 13',
#  'video\xa0— копия 14',
#  'video\xa0— копия 15',
#  'video\xa0— копия 16',
#  'video\xa0— копия 17',
#  'video\xa0— копия 18',
#  'video\xa0— копия 19',
#  'video\xa0— копия 2',
#  'video\xa0— копия 20',
#  'video\xa0— копия 21',
#  'video\xa0— копия 22',
#  'video\xa0— копия 23',
#  'video\xa0— копия 24',
#  'video\xa0— копия 25',
#  'video\xa0— копия 26',
#  'video\xa0— копия 27',
#  'video\xa0— копия 28',
#  'video\xa0— копия 29',
#  'video\xa0— копия 3',
#  'video\xa0— копия 30',
#  'video\xa0— копия 31',
#  'video\xa0— копия 32',
#  'video\xa0— копия 33',
#  'video\xa0— копия 34',
#  'video\xa0— копия 35',
#  'video\xa0— копия 36',
#  'video\xa0— копия 37',
#  'video\xa0— копия 38',
#  'video\xa0— копия 39',
#  'video\xa0— копия 4',
#  'video\xa0— копия 5',
#  'video\xa0— копия 6',
#  'video\xa0— копия 7',
#  'video\xa0— копия 8',
#  'video\xa0— копия 9',
#  'videoюьз4',
#  'videoюьз4\xa0— копия',
#  'wide_angle,_Two_PEOPLE_sit_at_a_small_table_suspended_on_a_fluffy_cloud,_sipping_tea_while_gazing_at_seed4137636075_share',
#  'young man swimming in colorful coral reef deep in ocean']
